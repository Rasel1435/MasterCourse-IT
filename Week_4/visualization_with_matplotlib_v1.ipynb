# %% [markdown]
# # Matplotlib

# %% [markdown]
# Import Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# Load The Data

# %%
df = pd.read_csv('./data/computer_science_scientists.csv')
df.head()
# Out:
#    World Rank  National Rank               Name  \
# 0           1              1      Yoshua Bengio
# 1           2              1       Anil K. Jain
# 2           3              2         Jiawei Han
# 3           4              1   Andrew Zisserman
# 4           5              3  Michael I. Jordan
#
#                                           Image URLs  \
# 0  https://s.research.com/images/aec914cd458a74e2...
# 1  https://s.research.com/images/2a967b4499197336...
# 2  https://s.research.com/images/42382fdef4ef0953...
# 3  https://s.research.com/images/2a3913cff9795e86...
# 4  https://s.research.com/images/56e4335ff90165e8...
#
#                                   Affiliation         Country  H-Index  \
# 0                      University of Montreal          Canada      208
# 1                   Michigan State University   United States      207
# 2  University of Illinois at Urbana-Champaign   United States      189
# 3                        University of Oxford  United Kingdom      188
# 4                    University of California        Berkeley      186
#
#    Citations  #DBLP
# 0     547028    847
# 1     260075   1009
# 2     216422   1266
# 3     282705    782
# 4     242697    836

# %% [markdown]
# Basic Plotting

# %%
world_rank = np.asarray(df['World Rank'])
dblp = np.asarray(df['#DBLP'])

plt.figure(figsize=(10, 6))
plt.plot(world_rank, label='World Rank')
plt.plot(dblp, label='#DBLP')

plt.xlabel('World Rank', fontsize=14)
plt.ylabel('#DBLP', fontsize=14)
plt.title('World Rank vs. #DBLP', fontsize=18, fontweight='bold', color='green')
plt.legend()
plt.grid(True)
plt.tick_params(axis='both', labelsize=12)
plt.show()

# %% [markdown]
# useful resource for more exploration </br>
# https://matplotlib.org </br>
# https://python-graph-gallery.com

# %% [markdown]
# ## Subplots

# %%
# National Rank, Citations, #DBLP, H-index

national_rank = np.asarray(df["National Rank"])[:50]
citations = np.asarray(df["Citations"])[:50]
dblp = np.asarray(df["#DBLP"])[:50]
hidx = np.asarray(df["H-Index"])[:50]
world_rank = np.asarray(df["World Rank"])[:50] - 1
names = np.asarray(df["Name"])[:50]

plt.rcParams["figure.figsize"] = (50,30)

fig, ax = plt.subplots(nrows=2,ncols=2)

ax[0,0].plot(national_rank,'r*')
ax[0,1].plot(citations,'g^')
ax[1,0].plot(dblp,'yo')
ax[1,1].plot(hidx,'b--')

ax[0,0].set_title("National Rank")
ax[0,1].set_title("Citations")
ax[1,0].set_title("#DBLP")
ax[1,1].set_title("H-index")

for x in range(2):
  for y in range(2):
    ax[x,y].set_xticks(ticks=world_rank)
    ax[x,y].set_xticklabels(labels=names, rotation='vertical')

plt.show()
